# %% [markdown]
# # BinX AI & ML Internship
#
# ## Week 1 — Day 1: Environment Setup
#
# ### Objective
#
# This notebook verifies that my Python virtual environment and the main
# data-science libraries are installed and working correctly.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib

print("Python executable:", sys.executable)
print("Python version:", sys.version.split()[0])
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
# Out:
# Python executable: C:\Users\HP\Desktop\BinX-AI-ML-Internship\Week-1\.venv\Scripts\python.exe
# Python version: 3.14.4
# NumPy version: 2.5.1
# Pandas version: 3.0.3
# Matplotlib version: 3.11.1

# %% [markdown]
# ## Jupyter Cell Execution Test
#
# The following cells demonstrate how variables created in one code cell
# can be used by another code cell running in the same kernel.

# %%
numbers = [10, 20, 30, 40, 50]

total = sum(numbers)

print("Numbers:", numbers)
print("Total:", total)
# Out:
# Numbers: [10, 20, 30, 40, 50]
# Total: 150

# %%
average = total / len(numbers)

print("Average:", average)
# Out:
# Average: 30.0
